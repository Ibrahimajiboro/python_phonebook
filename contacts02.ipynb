# %%
contacts = { }

print('Welcome to our address book...')
print('Kindly enter your details below...')
name1 = input ('Your name :  ')
address1 = input ('Your address :  ')
pnumber1 = input ('Your phone number :  ')
email1 = input ('your mail :  ')
contacts [name1] = [ address1 + ' , '  + pnumber1 + ' , ' + email1 ]
print (contacts['cnt1'])
confirm_cnt1 = input ('confirm your details and enter proceed. ')
print ('your details have been saved ')

print ('-----------------contact 1 added--------------------------------------------')

print('to add another contact, enter details below...')
name2 = input ('Your name :  ')
address2 = input ('Your address :  ')
pnumber2 = input ('Your phone number :  ')
email2 = input ('your mail :  ')
contacts ['cnt2'] = [ name2 + ' , ' + address2 + ' , '  + pnumber2 + ' , ' + email2 ]
print (contacts['cnt2'])
confirm_cnt2 = input ('confirm your details and enter proceed. ')
print ('your details have been saved ')
print (contacts['cnt2'])

print ('-----------------contact 2 added --------------------------------------------')

print('to add another contact, enter details below...')
name3 = input ('Your name :  ')
address3 = input ('Your address :  ')
pnumber3 = input ('Your phone number :  ')
email3 = input ('your mail :  ')
contacts ['cnt3'] = [ name3 + ' , ' + address3 + ' , '  + pnumber3 + ' , ' + email3 ]
print (contacts['cnt3'])
confirm_cnt3 = input ('confirm your details and enter proceed. ')
print ('your details have been saved ')
print (contacts['cnt3'])
print ('-----------------contact 3 added --------------------------------------------')

# %%
#add to contacts

contacts = { }

print('Welcome to our address book...')
print('Kindly enter your details below...')
name1 = input ('Your name :  ')
address1 = input ('Your address :  ')
pnumber1 = input ('Your phone number :  ')
email1 = input ('your mail :  ')
contacts [name1] = [ address1 + ' , '  + pnumber1 + ' , ' + email1 ]
confirm_contact1 = input ('enter confirm to see your saved details. ')
print (contacts[name1])
print ('your details have been saved ')
confirm_contact_list = input ('enter all contacts to see all saved contacts. ')
print (contacts)


print ('-----------------contact 1 added--------------------------------------------')


print('to add another contact, enter details below...')
name2 = input ('Your name :  ')
address2 = input ('Your address :  ')
pnumber2 = input ('Your phone number :  ')
email2 = input ('your mail :  ')
contacts [name2] = [ address2 + ' , '  + pnumber2 + ' , ' + email2 ]
confirm_contacts = input ('enter confirm to see your saved details. ')
print (contacts[name2])
print ('your details have been saved ')
confirm_contact_list = input ('enter all contacts to see all saved contacts. ')
print (contacts)
print ('-----------------contact 2 added --------------------------------------------')


print('to add another contact, enter details below...')
name3 = input ('Your name :  ')
address3 = input ('Your address :  ')
pnumber3 = input ('Your phone number :  ')
email3 = input ('your mail :  ')
contacts [name3] = [ address3 + ' , '  + pnumber3 + ' , ' + email3 ]
confirm_contacts = input ('enter confirm to see your saved details. ')
print (contacts[name3])
print ('your details have been saved ')
confirm_contact_list = input ('enter all contacts to see all saved contacts. ')
print (contacts)
print ('-----------------contact 3 added --------------------------------------------')


#delete contacts 


delete1 = input ('to delete contact from contacts list above, enter contact name : ')
del contacts[delete1]
confirm_contact_list = input ('enter all contacts to confirm if contact has been deleted. ')
print (contacts)


# edit contacts lists 


edit1 = input ('to edit a contact, enter name  : ')
edit2 = int (input ('to edit address enter 0, to edit number enter 1, to edit mail enter 2 : '))
edit3 = int(input ('Enter new detail  : '))
contacts [edit1] [edit2] = edit3
edit4 = input ('to view new contacts list, type contacts list in the dialogue box and press enter key : ')
print  (contacts)
# Out:
# Welcome to our address book...
# Kindly enter your details below...
# Your name :  ibra1
# Your address :  bimb1
# Your phone number :  0901
# your mail :  gmail1
# enter confirm to see your saved details. save
# ['bimb1 , 0901 , gmail1']
# your details have been saved
# enter all contacts to see all saved contacts. all contacts
# {'ibra1': ['bimb1 , 0901 , gmail1']}
# -----------------contact 1 added--------------------------------------------
# to add another contact, enter details below...
# Your name :  ibra2
# Your address :  bimb2
# Your phone number :  0902
# your mail :  gmail2
# enter confirm to see your saved details. confirm
# ['bimb2 , 0902 , gmail2']
# your details have been saved
# enter all contacts to see all saved contacts. all contacts
# {'ibra1': ['bimb1 , 0901 , gmail1'], 'ibra2': ['bimb2 , 0902 , gmail2']}
# -----------------contact 2 added --------------------------------------------
# to add another contact, enter details below...
# Your name :  ibra3
# ...

# %%
# edit contacts lists 

contacts = {'ade': '08026351245', 
            'yinka': ['07066332512','09036652558'] ,
            'bimbo': '09012558852'}

edit1 = input ('to view contacts list,type "contacts list" in the dialogue box and press enter key  : ')
print  (contacts)
edit2 = input ('to edit a contact number, enter name  : ')
edit3 = int (input ('to edit first number enter 0, to edit secomnd number enter 1  : '))
edit4 = input ('Enter new number  : ')
contacts [edit2] [edit3] = edit4
edit3 = input ('to view new contacts list, type contacts list in the dialogue box and press enter key : ')
print  (contacts)

# %%
contacts = { }
print ("PHONEBOOK")
print ("create contact, 1")
print ("eidt contact, 2")
print ("delete contact, ")








if i 3
    opt1 = input ('Your address :  ')

for i in range (1) :
    name1 = input ('Your name :  ')
    address1 = input ('Your address :  ')
    pnumber1 = input ('Your phone number :  ')
    email1 = input ('your mail :  ')
    contacts [name1] = [ address1 + ' , '  + pnumber1 + ' , ' + email1 ]
confirm_contacts = input ('enter save to see your saved details. ')
print (contacts)
# Out:
# Your name :  ibra1
# Your address :  bimb1
# Your phone number :  0901
# your mail :  gmail1
# enter save to see your saved details. save
# {'ibra1': ['bimb1 , 0901 , gmail1']}
