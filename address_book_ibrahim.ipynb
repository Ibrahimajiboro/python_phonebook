# %%
#add to contacts 

contacts = {'ade': '08026351245', 
            'yinka': ['07066332512','09036652558'] ,
            'bimbo': '09012558852'}

name4 = input ('contact name :  ')
address4 = input ('contact address :  ')
pnumber4 = input ('contact phone number :  ')
email4 = input ('contact mail :  ')

contacts [name4] = address4 +

print (contacts)

# %%
#delete contacts 

contacts = {'ade': '08026351245', 
            'yinka': ['07066332512','09036652558'] ,
            'bimbo': '09012558852'}

edit1 = input ('to view contacts list,type contacts list in the dialogue box and press enter key  : ')
print  (contacts)
edit2 = input ('to delete a contact, enter name and click control key : ')
del contacts[edit2]
edit3 = input ('to view new contacts list, type contacts list in the dialogue box and press enter key : ')
print  (contacts)

# %%
# edit contacts lists 

contacts = {'ade': '08026351245', 
            'yinka': ['07066332512','09036652558'] ,
            'bimbo': '09012558852', 'ibrahim' : '07063548746'}

edit1 = input ('to view contacts list,type "contacts list" in the dialogue box and press enter key  : ')
print  (contacts)
edit2 = input ('to edit a contact number, enter name  : ')
edit3 = int (input ('to edit first number enter 0, to edit secomnd number enter 1  : '))
edit4 = input ('Enter new number  : ')
contacts [edit2] [edit3] = edit4
edit3 = input ('to view new contacts list, type contacts list in the dialogue box and press enter key : ')
print  (contacts)

# %%
contacts = {}
trial = 0

while True:  
    print('[1]: Add Contact\n[2]: Edit Contact\n',
        '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
    
    option = input('Enter option: ')
    
    if option == '1':
        name = input('Enter name: ')
        if name in contacts:
            print(f'{name} already exist')
        else:
            add = input('Enter address: ')
            phones = []
            emails = []

            while True:
                phone = input(f'Enter phone no {len(phones)+1}: ')
                phones.append(phone)

                if input('Do you wish to add more no?(Y/N): ').upper() != 'Y':
                    break

            while True:
                email = input(f'Enter email {len(emails)+1}: ')
                emails.append(email)

                if input('Do you wish to add more no?(Y/N): ').upper() != 'Y':
                    break
                
            contacts[name] = {'add': add, 'phones': phones, 'emails': emails}
        
    elif option == '2':
        name = input('Enter name: ')
        if name in contacts:
            print(f'Name: {name}')
            print(f"Address: {contacts[name]['add']}")
            print(f"Phone Nos: {contacts[name]['phones']}")
            print(f"Emails: {contacts[name]['emails']}")
            
            while True:
                print('[1]: Edit Address\n[2]: Edit Phone Nos\n[3]: Edit Emails\n[#]: Previous Menu')
                option = input('Enter option: ')
                
                if option == '1':
                    old_add = contacts[name]['add']
                    add = input('Enter New Address: ')
                    contacts[name]['add'] = add
                    print(f'{old_add} successfully updated to {add}')
                elif option == '2':
                    while True:
                        print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                        option = input('Enter option: ')
                        
                        if option == '1':
                            new_phone = input('Enter New Phone No: ')
                            contacts[name]['phones'].append(new_phone)
                            print(f'{new_phone} successfully added.')
                        elif option == '2':
                            for i in range(len(contacts[name]['phones'])):
                                print(f"{i}: {contacts[name]['phones'][i]}")
                            
                            index = int(input('Enter option: '))
                            new_phone = input('Enter New Phone No: ')
                            contacts[name]['phones'][index] = new_phone
                            print(f'{new_phone} successfully updated.') 
                            
                        elif option == '3':
                            for i in range(len(contacts[name]['phones'])):
                                print(f"{i}: {contacts[name]['phones'][i]}")
                                
                            index = int(input('Enter option: '))
                            temp = contacts[name]['phones'][index]
                            del contacts[name]['phones'][index]
                            print(f'{temp} successfully deleted.') 
                            
                        elif option == '#':
                            break
                
                elif option == '3':
                    pass
                elif option == '#':
                    break
            
            
        else:
            print(f'{name} does not exist!')
        
    elif option == '3':
        name = input('Enter name: ')
        if name in contacts:
            del contacts[name]
            print(f'{name} successfully deleted!')
        else:
            print(f'{name} does not exist!')
        
    elif option == '4':
        name = input('Enter name: ')
        if name in contacts:
            print(f'Name: {name}')
            print(f"Address: {contacts[name]['add']}")
            print(f"Phone Nos: {contacts[name]['phones']}")
            print(f"Emails: {contacts[name]['emails']}")
        else:
            print(f'{name} does not exist!')
            
    elif option == '#':
        print('Goodbye!!!')
        break
    else:
        print('Invalid option')
        trial += 1
        
        if trial == 3:
            print('Technical Issue')
            break
# Out:
# [1]: Add Contact
# [2]: Edit Contact
# [3]: Delete Contact
# [4]: Search Contact
# [#]: Exit
# Enter option: 1
# Enter name: ibra 01
# Enter address: bomb01
# Enter phone no 1: 0901
# Do you wish to add more no?(Y/N): 09012
# Enter email 1: mail01
# Do you wish to add more no?(Y/N): y
# Enter email 2: mail02
# Do you wish to add more no?(Y/N): n
# [1]: Add Contact
# [2]: Edit Contact
# [3]: Delete Contact
# [4]: Search Contact
# [#]: Exit

# %% [markdown]
# #edit contacts lists
#
#
# contacts = {}
# trial = 0
#
# while True:
#     print('[1]: Add Contact\n[2]: Edit Contact\n',
#         '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
#
#     option = input('Enter option: ')
# #add contact
#     if option == '1':
#         name = input('Enter name: ')
#         if name in contacts:
#             print(f'{name} already exist')
#
#         #add contact details
#         else:
#             add = input('Enter address: ')
#             phones = []
#             emails = []
#
#             #add contacts phone
#             while True:
#                 phone = input(f'Enter phone no {len(phones)+1}: ')
#                 phones.append(phone)
#
#                 if input('Do you wish to add more no?(Y/N): ').upper() != 'Y':
#                     break
#
#             #add contacts mail
#             while True:
#                 email = input(f'Enter email {len(emails)+1}: ')
#                 emails.append(email)
#
#                 if input('Do you wish to add more no?(Y/N): ').upper() != 'Y':
#                     break
#
#             #add all new contact entries to contacts dictionary.
#             contacts[name] = {'add': add, 'phones': phones, 'emails': emails}
#
# #edit contact
#     elif option == '2':
#         name = input('Enter name: ')
#         if name in contacts:
#             print(f'Name: {name}')
#             print(f"Address: {contacts[name]['add']}")
#             print(f"Phone Nos: {contacts[name]['phones']}")
#             print(f"Emails: {contacts[name]['emails']}")
#
#             while True:
#                 print('[1]: Edit Address\n[2]: Edit Phone Nos\n[3]: Edit Emails\n[#]: Previous Menu')
#                 option = input('Enter option: ')
#
#                 #edit address
#                 if option == '1':
#                     old_add = contacts[name]['add']
#                     add = input('Enter New Address: ')
#                     contacts[name]['add'] = add
#                     print(f'{old_add} successfully updated to {add}')
#
#                 #edit phone
#                 elif option == '2':
#
#                     while True:
#                         print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
#                         option = input('Enter option: ')
#
#                         #add phone
#                         if option == '1':
#                             new_phone = input('Enter New Phone No: ')
#                             contacts[name]['phones'].append(new_phone)
#                             print(f'{new_phone} successfully added.')
#
#                         #edit phone
#                         elif option == '2':
#                             for i in range(len(contacts[name]['phones'])):
#                                 print(f"{i}: {contacts[name]['phones'][i]}")
#
#                             index = int(input('Enter option: '))
#                             new_phone = input('Enter New Phone No: ')
#                             contacts[name]['phones'][index] = new_phone
#                             print(f'{new_phone} successfully updated.')
#
#                         #delete phone
#                         elif option == '3':
#                             for i in range(len(contacts[name]['phones'])):
#                                 print(f"{i}: {contacts[name]['phones'][i]}")
#
#                             index = int(input('Enter option: '))
#                             temp = contacts[name]['phones'][index]
#                             del contacts[name]['phones'][index]
#                             print(f'{temp} successfully deleted.')
#
#                         #break edit phone
#                         elif option == '#':
#                             break
#
#                 #edit mail
#                 elif option == '3':
#                     #pass
#                     while True:
#                         print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
#                         option = input('Enter option: ')
#
#                         #add mail
#                         if option == '1':
#                             new_mail = input('Enter New Mail: ')
#                             contacts[name]['emails'].append(new_mail)
#                             print(f'{new_mail} successfully added.')
#
#                         #edit mail
#                         elif option == '2':
#                             for i in range(len(contacts[name]['emails'])):
#                                 print(f"{i}: {contacts[name]['emails'][i]}")
#
#                             indexme = int(input('Enter option: '))
#                             eidt_phone = input('Edit Mail: ')
#                             contacts[name]['emails'][indexme] =  eidt_phone
#                             print(f'{eidt_phone} successfully updated.')
#
#                         #delete mail
#                         elif option == '3':
#                             for i in range(len(contacts[name]['emails'])):
#                                 print(f"{i}: {contacts[name]['emails'][i]}")
#
#                             indexmd = int(input('Enter option: '))
#                             temp = contacts[name]['emails'][indexmd]
#                             del contacts[name]['emails'][indexmd]
#                             print(f'{temp} successfully deleted.')
#
#
#                         # break edit mail
#                         elif option == '#':
#                             break
#
#         # wrong edit contact name
#         else:
#             print(f'{name} does not exist!')
#
# #delete contact
#     elif option == '3':
#         name = input('Enter name: ')
#         if name in contacts:
#             del contacts[name]
#             print(f'{name} successfully deleted!')
#         else:
#             print(f'{name} does not exist!')
#
# #search contact
#     elif option == '4':
#         name = input('Enter name: ')
#         if name in contacts:
#             print(f'Name: {name}')
#             print(f"Address: {contacts[name]['add']}")
#             print(f"Phone Nos: {contacts[name]['phones']}")
#             print(f"Emails: {contacts[name]['emails']}")
#         else:
#             print(f'{name} does not exist!')
#
#     elif option == '#':
#         print('Goodbye!!!')
#         break
#     else:
#         print('Invalid option')
#         trial += 1
#
#         if trial == 3:
#             print('Technical Issue')
#             break

# %%
#edit contacts lists

contacts = {} 
trial = 0

while True:
    print('[1]: Add Contact\n[2]: Edit Contact\n', 
          '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
    
    option = input('Enter option: ')

    #add contact
    if option == '1': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'{name} already exist')

        #add contact address, phone & mail  
        else:
            add = input('Enter address: ')
            phones = []
            emails = []

            #add contacts phone
            while True:
                phone = input(f'Enter phone no {len(phones)+1}: ')
                phones.append(phone)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add contacts mail
            while True:
                email = input(f'Enter email {len(emails)+1}: ')
                emails.append(email)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add all new contact entries to contacts dictionary.
            contacts[name] = {'add': add, 'phones': phones, 'emails': emails}
   
    #edit contact
    elif option == '2': 
        name = input('Enter name: ') 
        
        if name in contacts: 
            print(f'Name: {name}') 
            print(f"Address: {contacts[name]['add']}") 
            print(f"Phone Nos: {contacts[name]['phones']}") 
            print(f"Emails: {contacts[name]['emails']}")

        while True:
            print('[1]: Edit Address\n[2]: Edit Phone Nos\n[3]: Edit Emails\n[#]: Previous Menu')
            option = input('Enter option: ')

            #edit address 
            if option == '1':
                old_add = contacts[name]['add']
                add = input('Enter New Address: ')
                contacts[name]['add'] = add
                print(f'{old_add} successfully updated to {add}')

            #edit phone number
            elif option == '2':

                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add phone
                    if option == '1':
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'].append(new_phone)
                        print(f'{new_phone} successfully added.')

                    #edit phone 
                    elif option == '2':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'][index] = new_phone
                        print(f'{new_phone} successfully updated.') 

                    #delete phone
                    elif option == '3':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        temp = contacts[name]['phones'][index]
                        del contacts[name]['phones'][index]
                        print(f'{temp} successfully deleted.') 

                    #break edit phone
                    elif option == '#':
                        break

            #edit mail 
            elif option == '3':
                #pass
                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add mail
                    if option == '1':
                        new_mail = input('Enter New Mail: ')
                        contacts[name]['emails'].append(new_mail)
                        print(f'{new_mail} successfully added.')

                    #edit mail    
                    elif option == '2':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexme = int(input('Enter option: '))
                        eidt_phone = input('Edit Mail: ')
                        contacts[name]['emails'][indexme] =  eidt_phone
                        print(f'{eidt_phone} successfully updated.')    

                    #delete mail    
                    elif option == '3':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexmd = int(input('Enter option: '))
                        temp = contacts[name]['emails'][indexmd]
                        del contacts[name]['emails'][indexmd]
                        print(f'{temp} successfully deleted.')     


                    # break edit mail          
                    elif option == '#':
                        break

    # wrong entry, edit contact     
    else:
        print(f'{name} does not exist!')
        
    #delete contact
    elif option == '3': 
        name = input('Enter name: ') 
        if name in contacts: 
            del contacts[name] 
            print(f'{name} successfully deleted!')
        else: print(f'{name} does not exist!')

    #search contact
    elif option == '4': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'Name: {name}') 
            print(f"Address: {contacts[name]['add']}") 
            print(f"Phone Nos: {contacts[name]['phones']}") 
            print(f"Emails: {contacts[name]['emails']}") 
        else: print(f'{name} does not exist!')

    #exit options        
    elif option == '#':
        print('Goodbye!!!')
        break
    
    else:
        print('Invalid option')
        trial += 1

    if trial == 3:
        print('Technical Issue')
        break

# %%
contacts = {} 
trial = 0

while True:
    print('[1]: Add Contact\n[2]: Edit Contact\n', 
          '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
    
    option = input('Enter option: ')

    #add contact
    if option == '1': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'{name} already exist')

        #add contact address, phone & mail  
        else:
            add = input('Enter address: ')
            phones = []
            emails = []

            #add contacts phone
            while True:
                phone = input(f'Enter phone no {len(phones)+1}: ')
                phones.append(phone)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add contacts mail
            while True:
                email = input(f'Enter email {len(emails)+1}: ')
                emails.append(email)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add all new contact entries to contacts dictionary.
            contacts[name] = {'add': add, 'phones': phones, 'emails': emails}
   
    #edit contact
    elif option == '2': 
        name = input('Enter name: ') 
        
        if name in contacts: 
            print(f'Name: {name}') 
            print(f"Address: {contacts[name]['add']}") 
            print(f"Phone Nos: {contacts[name]['phones']}") 
            print(f"Emails: {contacts[name]['emails']}")

        while True:
            print('[1]: Edit Address\n[2]: Edit Phone Nos\n[3]: Edit Emails\n[#]: Previous Menu')
            option = input('Enter option: ')

            #edit address 
            if option == '1':
                old_add = contacts[name]['add']
                add = input('Enter New Address: ')
                contacts[name]['add'] = add
                print(f'{old_add} successfully updated to {add}')

            #edit phone number
            elif option == '2':

                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add phone
                    if option == '1':
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'].append(new_phone)
                        print(f'{new_phone} successfully added.')

                    #edit phone 
                    elif option == '2':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'][index] = new_phone
                        print(f'{new_phone} successfully updated.') 

                    #delete phone
                    elif option == '3':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        temp = contacts[name]['phones'][index]
                        del contacts[name]['phones'][index]
                        print(f'{temp} successfully deleted.') 

                    #break edit phone
                    elif option == '#':
                        break

            #edit mail 
            elif option == '3':
                #pass
                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add mail
                    if option == '1':
                        new_mail = input('Enter New Mail: ')
                        contacts[name]['emails'].append(new_mail)
                        print(f'{new_mail} successfully added.')

                    #edit mail    
                    elif option == '2':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexme = int(input('Enter option: '))
                        eidt_phone = input('Edit Mail: ')
                        contacts[name]['emails'][indexme] =  eidt_phone
                        print(f'{eidt_phone} successfully updated.')    

                    #delete mail    
                    elif option == '3':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexmd = int(input('Enter option: '))
                        temp = contacts[name]['emails'][indexmd]
                        del contacts[name]['emails'][indexmd]
                        print(f'{temp} successfully deleted.')     


                    # break edit mail          
                    elif option == '#':
                        break

    # wrong entry, edit contact     
    else:
        print(f'{name} does not exist!')
        
    #delete contact
    elif option == '3': 
        name = input('Enter name: ') 
        if name in contacts: 
            del contacts[name] 
            print(f'{name} successfully deleted!')
        else: print(f'{name} does not exist!')

    #search contact
    elif option == '4': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'Name: {name}') 
            print(f"Address: {contacts[name]['add']}") 
            print(f"Phone Nos: {contacts[name]['phones']}") 
            print(f"Emails: {contacts[name]['emails']}") 
        else: print(f'{name} does not exist!')

    #exit options        
    elif option == '#':
        print('Goodbye!!!')
        break
    
    else:
        print('Invalid option')
        trial += 1

    if trial == 3:
        print('Technical Issue')
        break

# %%
while True:  
    print('[1]: Add Contact\n[2]: Edit Contact\n',
        '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
    break
# Out:
# [1]: Add Contact
# [2]: Edit Contact
# [3]: Delete Contact
# [4]: Search Contact
# [#]: Exit

# %%
while True:  
    print('[1]: Add Contact\n[2]: Edit Contact\n[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit' )
    break
# Out:
# [1]: Add Contact
# [2]: Edit Contact
# [3]: Delete Contact
# [4]: Search Contact
# [#]: Exit

# %%
emails = ['mail01', 'mail02', 'mail03' ]

email = input(f'Enter email {len(emails)+1}: ')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d2ba56d0293e> in <module>
#       1 emails = ['mail01', 'mail02', 'mail03' ]
#       2
# ----> 3 email = input(f'Enter email {len(emails)+1}: ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
