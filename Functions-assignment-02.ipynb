# %%
#edit contacts lists...general

contacts = {} 
trial = 0

while True:
    print('[1]: Add Contact\n[2]: Edit Contact\n', 
          '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
    
    option = input('Enter option: ')

    #add contact
    if option == '1': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'{name} already exist')

        #add contact address, phone & mail  
        else:
            add = input('Enter address: ')
            phones = []
            emails = []

            #add contacts phone
            while True:
                phone = input(f'Enter phone no {len(phones)+1}: ')
                phones.append(phone)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add contacts mail
            while True:
                email = input(f'Enter email {len(emails)+1}: ')
                emails.append(email)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add all new contact entries to contacts dictionary.
            contacts[name] = {'add': add, 'phones': phones, 'emails': emails}
   
    #edit contact
    elif option == '2': 
        name = input('Enter name: ') 
        
        if name in contacts: 
            print(f'Name: {name}') 
            print(f"Address: {contacts[name]['add']}") 
            print(f"Phone Nos: {contacts[name]['phones']}") 
            print(f"Emails: {contacts[name]['emails']}")

        while True:
            print('[1]: Edit Address\n[2]: Edit Phone Nos\n[3]: Edit Emails\n[#]: Previous Menu')
            option = input('Enter option: ')

            #edit address 
            if option == '1':
                old_add = contacts[name]['add']
                add = input('Enter New Address: ')
                contacts[name]['add'] = add
                print(f'{old_add} successfully updated to {add}')

            #edit phone number
            elif option == '2':

                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add phone
                    if option == '1':
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'].append(new_phone)
                        print(f'{new_phone} successfully added.')

                    #edit phone 
                    elif option == '2':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'][index] = new_phone
                        print(f'{new_phone} successfully updated.') 

                    #delete phone
                    elif option == '3':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        temp = contacts[name]['phones'][index]
                        del contacts[name]['phones'][index]
                        print(f'{temp} successfully deleted.') 

                    #break edit phone
                    elif option == '#':
                        break

            #edit mail 
            elif option == '3':
                #pass
                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add mail
                    if option == '1':
                        new_mail = input('Enter New Mail: ')
                        contacts[name]['emails'].append(new_mail)
                        print(f'{new_mail} successfully added.')

                    #edit mail    
                    elif option == '2':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexme = int(input('Enter option: '))
                        eidt_phone = input('Edit Mail: ')
                        contacts[name]['emails'][indexme] =  eidt_phone
                        print(f'{eidt_phone} successfully updated.')    

                    #delete mail    
                    elif option == '3':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexmd = int(input('Enter option: '))
                        temp = contacts[name]['emails'][indexmd]
                        del contacts[name]['emails'][indexmd]
                        print(f'{temp} successfully deleted.')     


                    # break edit mail          
                    elif option == '#':
                        break

        # wrong entry, edit contact     
        else:
            print(f'{name} does not exist!')
        
    #delete contact
    elif option == '3': 
        name = input('Enter name: ') 
        if name in contacts: 
            del contacts[name] 
            print(f'{name} successfully deleted!')
        else: print(f'{name} does not exist!')

    #search contact
    elif option == '4': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'Name: {name}') 
            print(f"Address: {contacts[name]['add']}") 
            print(f"Phone Nos: {contacts[name]['phones']}") 
            print(f"Emails: {contacts[name]['emails']}") 
        else: print(f'{name} does not exist!')

    #exit options        
    elif option == '#':
        print('Goodbye!!!')
        break
    
    else:
        print('Invalid option')
        trial += 1

    if trial == 3:
        print('Technical Issue')
        break

# %%
#edit contacts lists...general

contacts = {} 
trial = 0

while True:
    print('[1]: Add Contact\n[2]: Edit Contact\n', 
          '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
    
    option = input('Enter option: ')

    #add contact
    if option == '1': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'{name} already exist')

        #add contact address, phone & mail  
        else:
            add = input('Enter address: ')
            phones = []
            emails = []

            #add contacts phone
            while True:
                phone = input(f'Enter phone no {len(phones)+1}: ')
                phones.append(phone)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add contacts mail
            while True:
                email = input(f'Enter email {len(emails)+1}: ')
                emails.append(email)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add all new contact entries to contacts dictionary.
            contacts[name] = {'add': add, 'phones': phones, 'emails': emails}
   
    #edit contact
    elif option == '2': 
        name = input('Enter name: ') 
        
        if name in contacts: 
            print(edit_list(contacts, name)) 
           

        while True:
            print('[1]: Edit Address\n[2]: Edit Phone Nos\n[3]: Edit Emails\n[#]: Previous Menu')
            option = input('Enter option: ')

            #edit address 
            if option == '1':
                old_add = contacts[name]['add']
                add = input('Enter New Address: ')
                contacts[name]['add'] = add
                print(f'{old_add} successfully updated to {add}')

            #edit phone number
            elif option == '2':

                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add phone
                    if option == '1':
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'].append(new_phone)
                        print(f'{new_phone} successfully added.')

                    #edit phone 
                    elif option == '2':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'][index] = new_phone
                        print(f'{new_phone} successfully updated.') 

                    #delete phone
                    elif option == '3':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        temp = contacts[name]['phones'][index]
                        del contacts[name]['phones'][index]
                        print(f'{temp} successfully deleted.') 

                    #break edit phone
                    elif option == '#':
                        break

            #edit mail 
            elif option == '3':
                #pass
                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add mail
                    if option == '1':
                        new_mail = input('Enter New Mail: ')
                        contacts[name]['emails'].append(new_mail)
                        print(f'{new_mail} successfully added.')

                    #edit mail    
                    elif option == '2':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexme = int(input('Enter option: '))
                        eidt_phone = input('Edit Mail: ')
                        contacts[name]['emails'][indexme] =  eidt_phone
                        print(f'{eidt_phone} successfully updated.')    

                    #delete mail    
                    elif option == '3':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexmd = int(input('Enter option: '))
                        temp = contacts[name]['emails'][indexmd]
                        del contacts[name]['emails'][indexmd]
                        print(f'{temp} successfully deleted.')     


                    # break edit mail          
                    elif option == '#':
                        break

        # wrong entry, edit contact     
        else:
            print(f'{name} does not exist!')
        
    #delete contact
    elif option == '3': 
        name = input('Enter name: ') 
        if name in contacts: 
            del contacts[name] 
            print(f'{name} successfully deleted!')
        else: print(f'{name} does not exist!')

    #search contact
    elif option == '4': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'Name: {name}') 
            print(f"Address: {contacts[name]['add']}") 
            print(f"Phone Nos: {contacts[name]['phones']}") 
            print(f"Emails: {contacts[name]['emails']}") 
        else: print(f'{name} does not exist!')

    #exit options        
    elif option == '#':
        print('Goodbye!!!')
        break
    
    else:
        print('Invalid option')
        trial += 1

    if trial == 3:
        print('Technical Issue')
        break
# Out:
# [1]: Add Contact
# [2]: Edit Contact
# [3]: Delete Contact
# [4]: Search Contact
# [#]: Exit
# Enter option: 1
# Enter name: ibra1
# Enter address: add1
# Enter phone no 1: 0901
# Do you wish to add more?(Y/N): n
# Enter email 1: mail1
# Do you wish to add more?(Y/N): n
# [1]: Add Contact
# [2]: Edit Contact
# [3]: Delete Contact
# [4]: Search Contact
# [#]: Exit
# Enter option: ibra2
# Invalid option
# [1]: Add Contact
# [2]: Edit Contact
# [3]: Delete Contact
# [4]: Search Contact
# [#]: Exit
# Enter option: 1
# Enter name: ibra2
# Enter address: add2
# Enter phone no 1: 0902
# Do you wish to add more?(Y/N): n
# Enter email 1: mail2
# Do you wish to add more?(Y/N): n
# [1]: Add Contact
# [2]: Edit Contact
# [3]: Delete Contact
# [4]: Search Contact
# [#]: Exit
# Enter option: 2
# Enter name: ibra1
# Name: ibra1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6a5258366de2> in <module>
#      46
#      47         if name in contacts:
# ---> 48             print(edit_list(contacts, name))
#      49
#      50
#
# <ipython-input-24-f344301ea5ac> in edit_list(contacts, name)
#       1 def edit_list(contacts, name):
#       2     print(f'Name: {name}')
# ----> 3     print(f"Address: {cnontacts[name]['add']}")
#       4     print(f"Phone Nos: {contacts[name]['phones']}")
#       5     print(f"Emails: {contacts[name]['emails']}")
#
# NameError: name 'cnontacts' is not defined

# %%
def edit_address1(): 
    #edit address 
    if option == '1':
        old_add = contacts[name]['add']
        add = input('Enter New Address: ')
        contacts[name]['add'] = add
    return (f'{old_add} successfully updated to {add}')

# %%
#edit contacts lists.....complete sample 

contacts = {} 
trial = 0

while True:
    print('[1]: Add Contact\n[2]: Edit Contact\n', 
          '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
    
    option = input('Enter option: ')

    #add contact
    if option == '1': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'{name} already exist')

        #add contact address, phone & mail  
        else:
            add = input('Enter address: ')
            phones = []
            emails = []

            #add contacts phone
            while True:
                phone = input(f'Enter phone no {len(phones)+1}: ')
                phones.append(phone)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add contacts mail
            while True:
                email = input(f'Enter email {len(emails)+1}: ')
                emails.append(email)

                if input('Do you wish to add more?(Y/N): ').upper() != 'Y':
                    break

            #add all new contact entries to contacts dictionary.
            contacts[name] = {'add': add, 'phones': phones, 'emails': emails}
   
    #edit contact
    elif option == '2': 
        name = input('Enter name: ') 
        
        if name in contacts: 
            print (edit_list(contacts, name))

        while True:
            print('[1]: Edit Address\n[2]: Edit Phone Nos\n[3]: Edit Emails\n[#]: Previous Menu')
            option = input('Enter option: ')

            #edit address 
            if option == '1':
                old_add = contacts[name]['add']
                add = input('Enter New Address: ')
                contacts[name]['add'] = add
                print(formula1(old_add, add))

            #edit phone number
            elif option == '2':

                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add phone
                    if option == '1':
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'].append(new_phone)
                        print(f'{new_phone} successfully added.')

                    #edit phone 
                    elif option == '2':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        new_phone = input('Enter New Phone No: ')
                        contacts[name]['phones'][index] = new_phone
                        print(f'{new_phone} successfully updated.') 

                    #delete phone
                    elif option == '3':
                        for i in range(len(contacts[name]['phones'])):
                            print(f"{i}: {contacts[name]['phones'][i]}")

                        index = int(input('Enter option: '))
                        temp = contacts[name]['phones'][index]
                        del contacts[name]['phones'][index]
                        print(f'{temp} successfully deleted.') 

                    #break edit phone
                    elif option == '#':
                        break

            #edit mail 
            elif option == '3':
                #pass
                while True:
                    print('[1]: Add New\n[2]: Edit\n[3]: Delete\n[#]: Previous Menu')
                    option = input('Enter option: ')

                    #add mail
                    if option == '1':
                        new_mail = input('Enter New Mail: ')
                        contacts[name]['emails'].append(new_mail)
                        print(f'{new_mail} successfully added.')

                    #edit mail    
                    elif option == '2':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexme = int(input('Enter option: '))
                        eidt_phone = input('Edit Mail: ')
                        contacts[name]['emails'][indexme] =  eidt_phone
                        print(f'{eidt_phone} successfully updated.')    

                    #delete mail    
                    elif option == '3':
                        for i in range(len(contacts[name]['emails'])):
                            print(f"{i}: {contacts[name]['emails'][i]}")

                        indexmd = int(input('Enter option: '))
                        temp = contacts[name]['emails'][indexmd]
                        del contacts[name]['emails'][indexmd]
                        print(f'{temp} successfully deleted.')     


                    # break edit mail          
                    elif option == '#':
                        break

        # wrong entry, edit contact     
        else:
            print(f'{name} does not exist!')
        
    #delete contact
    elif option == '3': 
        name = input('Enter name: ') 
        if name in contacts: 
            del contacts[name] 
            print(f'{name} successfully deleted!')
        else: print(f'{name} does not exist!')

    #search contact
    elif option == '4': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'Name: {name}') 
            print(f"Address: {contacts[name]['add']}") 
            print(f"Phone Nos: {contacts[name]['phones']}") 
            print(f"Emails: {contacts[name]['emails']}") 
        else: print(f'{name} does not exist!')

    #exit options        
    elif option == '#':
        print('Goodbye!!!')
        break
    
    else:
        print('Invalid option')
        trial += 1

    if trial == 3:
        print('Technical Issue')
        break

# %%
contacts = {} 
trial = 0

while True:
    print('[1]: Add Contact\n[2]: Edit Contact\n', 
          '[3]: Delete Contact\n[4]: Search Contact\n[#]: Exit', sep='')
    
    option = input('Enter option: ')

    #add contact
    if option == '1': 
        name = input('Enter name: ') 
        if name in contacts: 
            print(f'{name} already exist')

        #add contact address, phone & mail  
        else:
            add = input('Enter address: ')
            phones = []
            emails = []
            
            #add all new contact entries to contacts dictionary.
            contacts[name] = {'add': add, formula1(phones, emails)}
# Out:
#   File "<ipython-input-14-f4ecd7f7440b>", line 23
#     contacts[name] = {'add': add, formula1(phones, emails)}
#                                                           ^
# SyntaxError: invalid syntax
